# %%
from __future__ import print_function
import pandas as pd
import numpy as np
import time
import copy
import datetime
import numba
import timeit
import xgboost as xgb
from sqlalchemy import create_engine
from sklearn.metrics import roc_auc_score

# %%
engine = create_engine('postgresql://postgres:@192.168.99.100:5432/nhlstats')
conn = engine.connect()
np.random.seed(42)

# %%
df = pd.read_sql('team_stats_public',engine,parse_dates=['gameDate']).set_index('gameId').sort_index()

# %%
def slice_team(df,teamSlct,varCode,hist_len=10):
    newdf = {}
    cols = [teamSlct+'_'+varCode+'_L'+x for x in np.arange(1,hist_len+1)[::-1].astype('str')]
    for team in df[teamSlct].unique():
        hist_vals = df[df[teamSlct] == team][varCode].values
        hist_idx = df[df[teamSlct] == team][varCode].index
        for date in hist_idx:
#             slicer = np.array(hist[hist.index < date].values)[-10:]
            pos = np.searchsorted(hist_idx,date)
            slicer = hist_vals[:pos][-hist_len:]
            if len(slicer)<hist_len:
                slicer = np.insert(slicer,0,-999*np.ones(hist_len-len(slicer)))
            newdf[date] = pd.Series(slicer,index=cols)
    return(newdf)

# %%
# %timeit dd = slice_team(df,'teamAbbrevHome','goalsForHome')
# Out:
# 1 loop, best of 3: 1.72 s per loop

# %%
@numba.jit
def slicer_jit(hist_vals,hist_idx,teamSlct,varCode,hist_len=10):
    returndf = {}
    # create columns
    cols = np.arange(1,hist_len+1)[::-1].astype('str')
    for i, item in enumerate(cols):
        cols[i] = teamSlct+'_'+varCode+'_L'+item
    # slicer itself
    for date in hist_idx:
        pos = np.searchsorted(hist_idx,date)
        slicer = hist_vals[:pos][-hist_len:]
        if len(slicer)<hist_len:
            slicer = list(-999*np.ones(hist_len-len(slicer))).append(slicer)
        returndf[date] = [slicer,cols]
#         returndf[date] = pd.Series(slicer,index=cols)
    return(returndf)

# %%
def slice_team_jit(df,teamSlct,varCode,hist_len=10):
    newdf = pd.DataFrame()
    for team in df[teamSlct].unique():
        hist_vals = df[df[teamSlct] == team][varCode].values
        hist_idx = df[df[teamSlct] == team].index
        rdf = slicer_jit(hist_vals,hist_idx,teamSlct,varCode)
    return(rdf)

# %%
# %timeit dd = slice_team_jit(df,'teamAbbrevHome','goalsForHome')
# Out:
# 1 loop, best of 3: 1.52 s per loop

# %%
hist_idx = df[df['teamAbbrevHome'] == 'EDM'].index

# %%
kk = pd.DataFrame.from_dict(dd)

# %%
dd
# Out:
# {2014020016: [None, array(['teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF'],
#         dtype='|S21')],
#  2014020030: [None, array(['teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF'],
#         dtype='|S21')],
#  2014020049: [None, array(['teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF'],
#         dtype='|S21')],
#  2014020072: [None, array(['teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF'],
#         dtype='|S21')],
#  2014020115: [None, array(['teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF'],
#         dtype='|S21')],
#  2014020183: [None, array(['teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF'],
#         dtype='|S21')],
#  2014020212: [None, array(['teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF'],
#         dtype='|S21')],
#  2014020229: [None, array(['teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF'],
#         dtype='|S21')],
#  2014020276: [None, array(['teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF'],
#         dtype='|S21')],
#  2014020320: [None, array(['teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF'],
#         dtype='|S21')],
#  2014020353: [array([2, 3, 7, 1, 2, 3, 0, 3, 1, 3]),
#   array(['teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF'],
#         dtype='|S21')],
#  2014020385: [array([3, 7, 1, 2, 3, 0, 3, 1, 3, 0]),
#   array(['teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF'],
#         dtype='|S21')],
#  2014020400: [array([7, 1, 2, 3, 0, 3, 1, 3, 0, 0]),
#   array(['teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF'],
#         dtype='|S21')],
#  2014020429: [array([1, 2, 3, 0, 3, 1, 3, 0, 0, 2]),
#   array(['teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF'],
#         dtype='|S21')],
#  2014
),
#   array(['teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF'],
#         dtype='|S21')],
#  2015020491: [array([3, 4, 1, 4, 4, 2, 4, 2, 4, 5]),
#   array(['teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF'],
#         dtype='|S21')],
#  2015020515: [array([4, 1, 4, 4, 2, 4, 2, 4, 5, 1]),
#   array(['teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF'],
#         dtype='|S21')],
#  2015020524: [array([1, 4, 4, 2, 4, 2, 4, 5, 1, 3]),
#   array(['teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF'],
#         dtype='|S21')],
#  2015020550: [array([4, 4, 2, 4, 2, 4, 5, 1, 3, 3]),
#   array(['teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF'],
#         dtype='|S21')],
#  2015020564: [array([4, 2, 4, 2, 4, 5, 1, 3, 3, 5]),
#   array(['teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF'],
#         dtype='|S21')],
#  2015020621: [array([2, 4, 2, 4, 5, 1, 3, 3, 5, 4]),
#   array(['teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF'],
#         dtype='|S21')],
#  2015020641: [array([4, 2, 4, 5, 1, 3, 3, 5, 4, 4]),
#   array(['teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF'],
#         dtype='|S21')],
#  2015020652: [array([2, 4, 5, 1, 3, 3, 5, 4, 4, 4]),
#   array(['teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF'],
#         dtype='|S21')],
#  2015020667: [array([4, 5, 1, 3, 3, 5, 4, 4, 4, 2]),
#   array(['teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF'],
#         dtype='|S21')],
#  2015020680: [array([5, 1, 3, 3, 5, 4, 4, 4, 2, 0]),
#   array(['teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF'],
#         dtype='|S21')],
#  2015020701: [array([1, 3, 3, 5, 4, 4, 4, 2, 0, 1]),
#   array(['teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF'],
#         dtype='|S21')],
#  2015020718: [array([3, 3, 5, 4, 4, 4, 2, 0, 1, 1]),
#   array(['teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF'],
#         dtype='|S21')],
#  2015020754: [array([3, 5, 4, 4, 4, 2, 0, 1, 1, 3]),
#   array(['teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF'],
#         dtype='|S21')],
#  2015020768: [array([5, 4, 4, 4, 2, 0, 1, 1, 3, 2]),
#   array(['teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF'],
#         dtype='|S21')],
#  2015020808: [array([4, 4, 4, 2, 0, 1, 1, 3, 2, 4]),
#   array(['teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF'],
#         dtype='|S21')],
#  2015020824: [array([4, 4, 2, 0, 1, 1, 3, 2, 4, 1]),
#   array(['teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF'],
#         dtype='|S21')],
#  2015020845: [array([4, 2, 0, 1, 1, 3, 2, 4, 1, 4]),
#   array(['teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF'],
#         dtype='|S21')],
#  2015020867: [array([2, 0, 1, 1, 3, 2, 4, 1, 4, 6]),
#   array(['teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF'],
#         dtype='|S21')],
#  2015020881: [array([0, 1, 1, 3, 2, 4, 1, 4, 6, 6]),
#   array(['teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF'],
#         dtype='|S21')],
#  2015020963: [array([1, 1, 3, 2, 4, 1, 4, 6, 6, 4]),
#   array(['teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF'],
#         dtype='|S21')],
#  2015020978: [array([1, 3, 2, 4, 1, 4, 6, 6, 4, 1]),
#   array(['teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF'],
#         dtype='|S21')],
#  2015021059: [array([3, 2, 4, 1, 4, 6, 6, 4, 1, 5]),
#   array(['teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF'],
#         dtype='|S21')],
#  2015021076: [array([2, 4, 1, 4, 6, 6, 4, 1, 5, 3]),
#   array(['teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF'],
#         dtype='|S21')],
#  2015021097: [array([4, 1, 4, 6, 6, 4, 1, 5, 3, 0]),
#   array(['teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF'],
#         dtype='|S21')],
#  2015021110: [array([1, 4, 6, 6, 4, 1, 5, 3, 0, 4]),
#   array(['teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF'],
#         dtype='|S21')],
#  2015021127: [array([4, 6, 6, 4, 1, 5, 3, 0, 4, 3]),
#   array(['teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF'],
#         dtype='|S21')],
#  2015021138: [array([6, 6, 4, 1, 5, 3, 0, 4, 3, 2]),
#   array(['teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF'],
#         dtype='|S21')],
#  2015021177: [array([6, 4, 1, 5, 3, 0, 4, 3, 2, 2]),
#   array(['teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF',
#          'teamAbbrevHome_goalsF', 'teamAbbrevHome_goalsF'],
#         dtype='|S21')]}

# %%
hist_vals = df[df['teamAbbrevHome'] == 'EDM']['goalsForHome'].values
hist_idx = df[df['teamAbbrevHome'] == 'EDM'].index
hist_idx
# Out:
# Int64Index([2005020014, 2005020036, 2005020070, 2005020092, 2005020111,
#             2005020183, 2005020289, 2005020305, 2005020314, 2005020370,
#             ...
#             2015020936, 2015021000, 2015021026, 2015021036, 2015021049,
#             2015021065, 2015021083, 2015021137, 2015021176, 2015021201],
#            dtype='int64', name=u'gameId', length=445)

# %%
print(np.searchsorted(hist_idx,2005020470))
# Out:
# 13

# %%
hist_vals[:13][-10:]
# Out:
# array([4, 3, 2, 3, 1, 5, 6, 3, 1, 2, 5, 4, 5])
